# %% [markdown]
# # Importes

# %%
import convert

# %% [markdown]
# # Ejecución

# %%
# Conversión de archivos de anotaciones de XML a YOLO
convert.convert_xml2yolo({"pothole": 0}, r'../DATA/annotated-images/labels')
# Out:
# wrote ../DATA/annotated-images/labels/img-1.txt
# wrote ../DATA/annotated-images/labels/img-10.txt
# wrote ../DATA/annotated-images/labels/img-100.txt
# wrote ../DATA/annotated-images/labels/img-101.txt
# wrote ../DATA/annotated-images/labels/img-102.txt
# wrote ../DATA/annotated-images/labels/img-103.txt
# wrote ../DATA/annotated-images/labels/img-104.txt
# wrote ../DATA/annotated-images/labels/img-105.txt
# wrote ../DATA/annotated-images/labels/img-106.txt
# wrote ../DATA/annotated-images/labels/img-107.txt
# wrote ../DATA/annotated-images/labels/img-108.txt
# wrote ../DATA/annotated-images/labels/img-109.txt
# wrote ../DATA/annotated-images/labels/img-11.txt
# wrote ../DATA/annotated-images/labels/img-110.txt
# wrote ../DATA/annotated-images/labels/img-111.txt
# wrote ../DATA/annotated-images/labels/img-112.txt
# wrote ../DATA/annotated-images/labels/img-113.txt
# wrote ../DATA/annotated-images/labels/img-114.txt
# wrote ../DATA/annotated-images/labels/img-115.txt
# ...
